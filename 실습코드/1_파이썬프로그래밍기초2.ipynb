# %% [markdown]
# # 1. 파이썬 프로그래밍 기초 (조건문/반복문/함수)

# %% [markdown]
# ## 1.1 조건문
# - 알고리즘을 개발하기위해 ‘조건문’은 없어서는 안되는 부분입니다.
# - 조건문은 사람이 어떤 상황에 놓여져 있을 때, 판단하는 것처럼 컴퓨터에게 특정 조건이 주어졌을 때 행동해야 하는 방법을 인식시켜주는 부분이라고 생각할 수 있습니다.
# - 조건문의 기본적인 구조는 '조건'이후에 콜론(:)으로 구분하여, '조건'과 '행동'을 구분하는 것이라고 할 수 있습니다.

# %% [markdown]
# - 조건문에서 사용하는 연산자는 다음과 같습니다.
#
# | 비교 연산자 | 내용 |
# |:---:|:---:|
# |x<y|x가 y보다 작다.|
# |x>y|x가 y보다 크다.|
# |x==y| x가 y와 같다.|
# |x!=y| x가 y와 같지 않다.|
# |x>=y| x가 y보다 크거나 같다.|
# |x<=y| x가 y보다 작거나 같다.|
# |x조건 or y조건| x조건과 y조건 둘 중에 하나만 참이면 참|
# |x조건 and y조건| x조건과 y조건 모두 참이어야 참|
# |not x조건| x조건이 거짓이면 참|
# |x in 리스트/튜플/문자열| 리스트/튜플/문자열 안에 x가 있으면 참|
# |x not in 리스트/튜플/문자열| 리스트/튜플/문자열 안에 x가 있지 않으면 참|

# %%
# if문 (if/else)
# 전체 5판의 게임 중 게임에서 이긴 총 수
win = 3

if win >=3 :
  print('축하합니다. 승급하셨습니다.')
else :
  print ('안타깝게도 승급에 실패하셨습니다.')
# Out:
# 축하합니다. 승급하셨습니다.

# %%
# elif문
# 전체 5판의 게임 중 게임에서 이긴 총 수
win = 3

if win >=3 :
  print('축하합니다. 승급하셨습니다.')
elif win >=2 :
  print('단 한판의 기회를 더 드리겠습니다. 대신 패배하는 경우 등급이 하락합니다.')
else :
  print ('안타깝게도 승급에 실패하셨습니다.')
# Out:
# 축하합니다. 승급하셨습니다.

# %% [markdown]
# ### 1.1.1. 조건문 연습
#
# 변수 age가
#
# `0이상 9이하 이면 '영유아’/10이상 19이하 이면 '10대',`
#
# `20이상 29이하 이면 '20대’/30이상 39이하 이면 '30대'`
#
# `40이상 49이하 이면 '40대’/아무것도 해당하지 않으면 '기타’`
#
# 가 출력하는 조건문을 생성해라

# %% [markdown]
# ## 1.2 반복문
# - 동일한 동작을 여러 번 반복해야 하는 경우, 코드를 한 줄씩 입력하는 것은 매우 비효율적인 일이며, 많은 ‘행’ 데이터를 확인하거나 처리하기 위해서는 반복문을 반드시 활용할 수 있어야 합니다.
# - 반복문에는 상황에 따라 while문 for문과 같은 문법을 사용합니다.

# %% [markdown]
# ### 1.2.1. while 문
# - while문은 조건문이 참인 '동안' 그 안에 속해 있는 문장들을 반복해서 수행하는 문법입니다.
# - `break`는 반복문에서 사용되는 함수로 반복문 내부에서 강제로 빠져나오고 싶을 때 사용하는 문법입니다.
# - `continue`는 제시하는 특정 조건을 만족하는 경우, 그 하위 문장을 실행하지 않고 반복문의 시작지점으로 위치를 이동시키는 문법입니다.

# %%
# while 문
playGame = 0
while playGame <= 3:
  print('게임을 %d 판 했습니다.' %playGame)

  if playGame == 3:
    print('마지막 게임이었습니다.')

  playGame = playGame + 1
# Out:
# 게임을 0 판 했습니다.
# 게임을 1 판 했습니다.
# 게임을 2 판 했습니다.
# 게임을 3 판 했습니다.
# 마지막 게임이었습니다.

# %%
# continue 사용
a = 0
while a < 6:
  a = a+1
  if a % 2 == 0: continue
  print(a)
# Out:
# 1
# 3
# 5

# %%
# break 사용
item   = 4
money  = 30000
myitem = 0

while money > 1300 :
  print("아이템을 구매합니다.")
  item = item - 1
  myitem = myitem + 1
  money = money - 500
  print("나의 아이템은 %d개, 남은 돈은 %d원입니다." %(myitem, money))
  print("상점에 남은 아이템은 "+str(item)+"개 입니다.\n")
  if not item:
    print("아이템이 전부 소진되었습니다. 상점 문을 닫습니다.")
    break
# Out:
# 아이템을 구매합니다.
# 나의 아이템은 1개, 남은 돈은 29500원입니다.
# 상점에 남은 아이템은 3개 입니다.
#
# 아이템을 구매합니다.
# 나의 아이템은 2개, 남은 돈은 29000원입니다.
# 상점에 남은 아이템은 2개 입니다.
#
# 아이템을 구매합니다.
# 나의 아이템은 3개, 남은 돈은 28500원입니다.
# 상점에 남은 아이템은 1개 입니다.
#
# 아이템을 구매합니다.
# 나의 아이템은 4개, 남은 돈은 28000원입니다.
# 상점에 남은 아이템은 0개 입니다.
#
# 아이템이 전부 소진되었습니다. 상점 문을 닫습니다.

# %% [markdown]
# ### 1.2.2. for문
# - for문은 가장 기본적으로 대표적인 반복문으로 범위를 지정하여 범위에 해당하는 내용을 하나씩 순차적으로 대입하여 수행할 문장을 반복하는 문법입니다.
# - `for 변수 in 범위 :`를 시작으로 작성합니다.

# %%
# for문 기본구조
test_list = ['one', 'two', 'three']
for i in test_list :
  print(i)
# Out:
# one
# two
# three

# %%
# 튜플 리스트 예제
a = [(1,2), (3,4), (5,6)]
for (f, l) in a :
  print(f+l)
# Out:
# 3
# 7
# 11

# %%
# range 함수를 활용한 for문
# range 함수는 range(시작 숫자, 마지막 숫자+!)을 작성하여 사용합니다.
# 1부터 10까지 더하기
sum = 0
for i in range(1, 11) :
  sum = sum + i
print(sum)
# Out:
# 55

# %% [markdown]
# ### 1.2.3. for문 문제
# - 구구단 3단을 출력해봅시다 (27까지)

# %%
for i in range(1, 10) :
  print(3 * i)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27

# %% [markdown]
# ## 1.3. 함수 만들기
# - 현업 혹은 실제로 데이터 분석을 하는 경우 특정 로직이 여러 군데에서 활용되는 경우가 많습니다.
# - 이러한 경우 동일한 코드를 여러 번 반복해서 사용하는 것보다 나만의 함수로 정의하여 사용하는 것이 훨씬 효율적인 방법입니다.
# - 함수는 기본적으로 `def`함수를 사용하며 `def 함수명(입력인수):`의 형태로 사용합니다.

# %%
def mySum(a, b) :
  print(a + b)

mySum(1,2)

# %%
def mySum(a, b) :
  return a + b

mySum(1, 2)

# %%
def mySum_fn(method, *args) :     # method 문자열 인자, *args 가변인자 (기본 튜플로 받음)
  if method == 'sum' :
    result = 0
    for i in args :
      result = result + i
  elif method == 'mul' :
    result = 1
    for i in args :
      result = result * i
  return result

mySum_fn('sum', 1,2,3,4)
# Out:
# 10

# %%
mySum_fn('mul', 1,2,3,4)
# Out:
# 24
